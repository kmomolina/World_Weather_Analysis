# %%
# Import the required libraries
import hvplot.pandas
import pandas as pd

# %%
# Import the required libraries
import requests

# Import API key
from config import geoapify_key

# %%
# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID          City Country                 Date      Lat       Lng  \
# 0        0          Azul      AR  2022-12-07 20:52:56 -36.7770  -59.8585
# 1        1        Albany      US  2022-12-07 20:52:28  42.6001  -73.9662
# 2        2  Puerto Ayora      EC  2022-12-07 20:52:56  -0.7393  -90.3518
# 3        3      Bengkulu      ID  2022-12-07 20:49:28  -3.8004  102.2655
# 4        4   Panama City      PA  2022-12-07 20:50:00   8.9936  -79.5197
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     97.57        16          67       18.14
# 1     57.72        91         100        1.01
# 2     82.36        89           8        7.00
# 3     74.82        90          99        4.88
# 4     87.13        55          20       16.11

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure the map plot_1
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM"
)
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]

# %%
# Configure the map plot_2
map_plot_2 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500
)

# Display the map plot
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]

# %%
# Configure the map plot_3
map_plot_3 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 0.5,
    color = "City"
)

# Display the map plot
map_plot_3
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp)

# %%
# Configure the map plot_4
map_plot_4 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriNatGeo",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 0.5,
    color = "City"
)

# Display the map plot
map_plot_4
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp)

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))

# %%
preferred_cities_df = city_data_df.loc[
    (city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)
]
preferred_cities_df.head(10)
# Out:
#     City_ID           City Country                 Date      Lat       Lng  \
# 2         2   Puerto Ayora      EC  2022-12-07 20:52:56  -0.7393  -90.3518
# 4         4    Panama City      PA  2022-12-07 20:50:00   8.9936  -79.5197
# 6         6       Progreso      MX  2022-12-07 20:50:12  21.2833  -89.6667
# 8         8        Cayenne      GF  2022-12-07 20:52:58   4.9333  -52.3333
# 12       12  Cockburn Town      TC  2022-12-07 20:52:59  21.4612  -71.1419
# 15       15         Avarua      CK  2022-12-07 20:50:55 -21.2078 -159.7750
# 17       17        Rikitea      PF  2022-12-07 20:53:00 -23.1203 -134.9692
# 23       23         Faanui      PF  2022-12-07 20:53:02 -16.4833 -151.7500
# 30       30     Georgetown      MY  2022-12-07 20:53:04   5.4112  100.3354
# 31       31     Butaritari      KI  2022-12-07 20:53:05   3.0707  172.7902
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 2      82.36        89           8        7.00
# 4      87.13        55          20       16.11
# 6      87.12        73           1       16.44
# 8      82.44        74           0       10.36
# 12     78.26        55          11       19.01
# 15     80.65        78          20       12.66
# 17     75.38        79          20       19.57
# 23     81.00        74         100       21.05
# 30     80.53        91          20        5.75
# 31     80.13        81          96       12.12

# %%
preferred_cities_df.count()
# Out:
# City_ID       175
# City          175
# Country       175
# Date          175
# Lat           175
# Lng           175
# Max Temp      175
# Humidity      175
# Cloudiness    175
# Wind Speed    175
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#              City Country  Max Temp      Lat       Lng Hotel Name
# 2    Puerto Ayora      EC     82.36  -0.7393  -90.3518
# 4     Panama City      PA     87.13   8.9936  -79.5197
# 6        Progreso      MX     87.12  21.2833  -89.6667
# 8         Cayenne      GF     82.44   4.9333  -52.3333
# 12  Cockburn Town      TC     78.26  21.4612  -71.1419
# 15         Avarua      CK     80.65 -21.2078 -159.7750
# 17        Rikitea      PF     75.38 -23.1203 -134.9692
# 23         Faanui      PF     81.00 -16.4833 -151.7500
# 30     Georgetown      MY     80.53   5.4112  100.3354
# 31     Butaritari      KI     80.13   3.0707  172.7902

# %%
# Set initial parameters to search for a hotel.
radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
}

# %%
# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    latitude = row["Lat"]
    longitude = row["Lng"]


    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"

    # Set up the base URL for the Geoapify Places API.
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionary
    name_address = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = name_address.json()

# Get the first hotel from the results and store the name
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
    # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

hotel_df.head()
# Out:
#              City Country  Max Temp      Lat      Lng          Hotel Name
# 2    Puerto Ayora      EC     82.36  -0.7393 -90.3518    Muyuyo Galápagos
# 4     Panama City      PA     87.13   8.9936 -79.5197        Aloft Panama
# 6        Progreso      MX     87.12  21.2833 -89.6667    Hotel Costa Club
# 8         Cayenne      GF     82.44   4.9333 -52.3333       Central Hôtel
# 12  Cockburn Town      TC     78.26  21.4612 -71.1419  The Salt Raker Inn

# %%
# Configure the map
hotel_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 1,
    color = "City"
    hover_cols = ["Hotel Name", "Country"] 
)

# Display the map plot
hotel_map
# Out:
#   File "C:\Users\kirst\AppData\Local\Temp\ipykernel_49640\3659520228.py", line 12
#     hover_cols = ["Hotel Name", "Country"]
#              ^
# SyntaxError: invalid syntax
